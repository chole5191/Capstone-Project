# %% [markdown]
# ## Data Description

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# This is the data I used for this project. Specially, Im going to use the Scarborough, Ontario datast.

# %% [markdown]
# In order to get information about the area I'm looking for, I will use Foursquare location information. Foursquare is the most trusted, independent location data platform for understanding how people move through the real world. From this platform, longitude and latitude of the place can be obtained as well as venue, name
